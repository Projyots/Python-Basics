# %% [markdown]
# # 1. Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
def div_range(number):
    
    if 2000 <= number <=3200:
        if number % 7 == 0 and number % 5 != 0:
            print("The number {} meets the criteria".format(number))
        else:
            print("The number is either not divisible by 7 or not a multiple of 5")
    else:
        print("The number is out of range")

# %%
for i in range(2000,3201):
    print(div_range(i))
# Out:
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number 2002 meets the criteria
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number 2009 meets the criteria
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# The number is either not divisible by 7 or not a multiple of 5
# None
# ...

# %% [markdown]
# # 2. Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
def rev_name(fname, lname):
    
    revName = lname[::-1] + ' ' + fname[::-1]
    return revName

# %%
f_name = input()
l_name = input()

rev_name(f_name,l_name)
# Out:
# proj
# sri
# 'irs jorp'

# %% [markdown]
# # 3.  Write a Python program to find the volume of a sphere with diameter 12 cm.
# Formula: V=4/3 * π * r

# %%
def Volume_sphere(radius):
    
    Vol = 4/3 * 22/7 * radius
    
    print("%2.f" % Vol + ' cubic units')

# %%
Volume_sphere(7)
# Out:
# 29 cubic units
